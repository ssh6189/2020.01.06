# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

origin = cv2.imread("C:/Users/student/Desktop/homework.png")
rgb = cv2.cvtColor(origin, cv2.COLOR_BGR2RGB)

#h, s, v = cv2.split(cv2.cvtColor(origin, cv2.COLOR_BGR2HSV)) #슬라이싱보다 훨씬 빠르다.

#plt.hist(h.ravel(), 256, [0, 256], color = 'r');

#plt.hist(s.ravel(), 256, [0, 256], color = 'g');

#plt.hist(v.ravel(), 256, [0, 256], color = 'b');

#plt.show()

#hi = plt.hist(h.ravel(), 256, [0, 256])
#print(hi[0])
#print(hi[1])
#print(hi[2])

#hg = plt.hist(g.ravel(), 256, [0, 256], color = 'g')

#value = (np.where(hi[0] == np.max(hi[0])))[0][0]
#print(value)

#r = rgb[:, :, 0]
#g = rgb[:, :, 1]
#b = rgb[:, :, 2]

#maxg = (np.where(hg[0] == np.max(hg[0])))[0][0]
#print(maxg)

#초록색 배경만 전부 하얀색으로

for r in range(rgb.shape[0]):
    for c in range(rgb.shape[1]):
        if g[r, c] > 240:
            rgb[r, c, 0] = 255
            rgb[r, c, 1] = 255
            rgb[r, c, 2] = 255
        else:
            origin[r, c, 0] = origin[r, c, 0];
            origin[r, c, 1] = origin[r, c, 1];
            origin[r, c, 2] = origin[r, c, 2];

#b = cv2.cvtColor(rgb, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.show()
